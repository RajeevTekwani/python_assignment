# %%
import os 
file = open("demo.txt","r")
for i in range(5):
    data = file.readline()
    print(data)
    ls = data.split()
    print(ls)

    print(f"the words in the line {i+1} are :",len(ls))
# Out:
# my name is rajeev
#
# ['my', 'name', 'is', 'rajeev']
# the words in the line 1 are : 4
# i am from JECRC
#
# ['i', 'am', 'from', 'JECRC']
# the words in the line 2 are : 4
# i am a python developer
#
# ['i', 'am', 'a', 'python', 'developer']
# the words in the line 3 are : 5
# i have worked in nasa
#
# ['i', 'have', 'worked', 'in', 'nasa']
# the words in the line 4 are : 5
# bye bye
#
# ['bye', 'bye']
# the words in the line 5 are : 2

# %%
|
