# %%
import pandas as pd
df = pd.read_csv("tip_data.csv")
import matplotlib.pyplot as plt
plt.hist(df["tip"],edgecolor="black",color="r")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("tip_data.csv")
import matplotlib.pyplot as plt
plt.hist(df["total_bill"],edgecolor="black",color="pink")
plt.show()
